# %%
import torch
import torch.nn as nn
import jieba

# %%
text = "自然语言是由文字构成的，而语言的含义是由单词构成的。即单词是含义的最小单位。因此为了让计算机理解自然语言，首先要让它理解单词含义。"

# %%
# 1.分词
original_words = jieba.lcut(text)
print(original_words)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\lenovo\AppData\Local\Temp\jieba.cache
# Loading model cost 0.330 seconds.
# Prefix dict has been built successfully.
# ['自然语言', '是', '由', '文字', '构成', '的', '，', '而', '语言', '的', '含义', '是', '由', '单词', '构成', '的', '。', '即', '单词', '是', '含义', '的', '最小', '单位', '。', '因此', '为了', '让', '计算机', '理解', '自然语言', '，', '首先', '要', '让', '它', '理解', '单词', '含义', '。']

# %%
# 自定义一组停用词
stopwords={"的","是","而","由","，","。"}

# %%
# 2.过滤停用词和标点符号，构建词表
words=[word for word in original_words if word not in stopwords]
print(words)
# Out:
# ['自然语言', '文字', '构成', '语言', '含义', '单词', '构成', '即', '单词', '含义', '最小', '单位', '因此', '为了', '让', '计算机', '理解', '自然语言', '首先', '要', '让', '它', '理解', '单词', '含义']

# %%
# 3.构建词表(id2word)
id2word=list(set(words))
print(id2word)
# Out:
# ['因此', '构成', '单词', '语言', '即', '计算机', '要', '理解', '最小', '让', '自然语言', '首先', '含义', '单位', '为了', '文字', '它']

# %%
# 4.构建字典，保存word到索引号的映射(word2id)
word2id=dict()
for id,word in enumerate(id2word):
    word2id[word] = id
print(word2id)
# Out:
# {'因此': 0, '构成': 1, '单词': 2, '语言': 3, '即': 4, '计算机': 5, '要': 6, '理解': 7, '最小': 8, '让': 9, '自然语言': 10, '首先': 11, '含义': 12, '单位': 13, '为了': 14, '文字': 15, '它': 16}

# %%
# 5.构建一个嵌入层
embed=nn.Embedding(num_embeddings=len(id2word),embedding_dim=5)

# %%
# 6.前向传播，传入单词索引号，得到词向量
for id,word in enumerate(id2word):
    word_vec=embed(torch.tensor(id))
    print(f"{id:>2}:{word:8}\t{word_vec.detach().numpy()}")
# Out:
#  0:因此      	[-0.5114776   1.6775956   1.1369033   0.4703153   0.38154987]
#  1:构成      	[-0.48732334 -0.29510605 -1.4927686  -0.43661445  1.9115536 ]
#  2:单词      	[-1.5288757   0.36567837 -1.1940655  -0.03151391  1.1453006 ]
#  3:语言      	[ 0.00914208  1.002132   -1.0672776  -0.5020757  -1.3755345 ]
#  4:即       	[-0.36551455  1.1120274   1.9839563  -0.5720622  -1.0057228 ]
#  5:计算机     	[-0.7765986   1.2351924  -0.9630022  -0.07567723 -0.9900391 ]
#  6:要       	[ 1.4929705  -0.9533523  -0.04380385  0.43557736  0.37269536]
#  7:理解      	[0.6257543  0.7974053  1.0620154  0.03330511 1.2210506 ]
#  8:最小      	[ 0.82180595 -0.9759072  -1.1014239  -0.9030971  -1.4176325 ]
#  9:让       	[ 1.5646392   0.3808284  -0.20148678  1.0271969   0.10662144]
# 10:自然语言    	[-0.08815522 -1.2452868  -0.26069993 -0.8623293  -1.0257902 ]
# 11:首先      	[1.6538944  0.63187647 0.13398509 1.5991083  0.8085012 ]
# 12:含义      	[-0.9746091  -0.48950732 -0.6433753  -0.666556   -1.6032636 ]
# 13:单位      	[ 0.24824359 -0.33193356  0.7542115  -2.031227   -0.09057675]
# 14:为了      	[-0.5298021  -0.02780834 -0.23894794 -0.9371511  -1.7134724 ]
# 15:文字      	[ 0.3891111  -1.7763194   0.35113084  1.0642354  -0.7846703 ]
# 16:它       	[ 0.03291511 -0.50232565  0.336866   -1.3739789   0.5583022 ]
