# %%
import torch
import torch.nn as nn

# %%
x=torch.randint(1,10,(10,),dtype=torch.float32)

# %%
# 定义一个Dropout层
dropout=nn.Dropout(p=0.5)

# %%
y=dropout(x)

# %%
print(x)
print(y)
# Out:
# tensor([2., 6., 1., 5., 2., 3., 2., 3., 2., 7.])
# tensor([ 0., 12.,  0.,  0.,  4.,  0.,  0.,  0.,  0.,  0.])
