# %%
import torch

# %%
x=torch.randn(3,5)
print(x)
# Out:
# tensor([[-0.5003, -1.2742,  0.1393,  0.3234, -0.3681],
#         [-0.8328, -0.6226, -1.7991, -0.9150,  0.8247],
#         [ 0.2027,  1.8645, -0.6395,  0.3857, -0.0499]])

# %%
y=torch.softmax(x,dim=1)
print(y)
# Out:
# tensor([[0.1476, 0.0681, 0.2797, 0.3363, 0.1684],
#         [0.1139, 0.1405, 0.0433, 0.1049, 0.5974],
#         [0.1152, 0.6072, 0.0496, 0.1384, 0.0895]])
