# %%
import jieba

# %%
text="小明毕业于北京大学计算机系"

# %% [markdown]
# # 第一节 分词模式

# %%
# 1.精确模式
jieba.lcut(text) #返回一个列表，cut返回一个生成器更省内存
# Out:
# ['小明', '毕业', '于', '北京大学', '计算机系']

# %%
# 2.全模式
jieba.lcut(text,cut_all=True)
# Out:
# ['小', '明', '毕业', '于', '北京', '北京大学', '大学', '计算', '计算机', '计算机系', '算机', '系']

# %%
# 3.搜索引擎模式
jieba.lcut_for_search(text)
# Out:
# ['小明', '毕业', '于', '北京', '大学', '北京大学', '计算', '算机', '计算机', '计算机系']

# %% [markdown]
# # 第二节 自定义词典

# %%
jieba.load_userdict("./data/user_dict.txt")

# %%
jieba.lcut("随着云计算技术的普及，越来越多企业开始采用云原生架构来部署服务，并借助大模型能力提升智能化水平，实现业务流程的自动化与智能决策。")
# Out:
# ['随着',
#  '云计算',
#  '技术',
#  '的',
#  '普及',
#  '，',
#  '越来越',
#  '多',
#  '企业',
#  '开始',
#  '采用',
#  '云原生',
#  '架构',
#  '来',
#  '部署',
#  '服务',
#  '，',
#  '并',
#  '借助',
#  '大模型',
#  '能力',
#  '提升',
#  '智能化',
#  '水平',
#  '，',
#  '实现',
#  '业务流程',
#  '的',
#  '自动化',
#  '与',
#  '智能',
#  '决策',
#  '。']
